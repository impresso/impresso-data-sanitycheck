# %% [markdown]
# # Snapshotting

# %% [markdown]
# ## IML snapshots

# %% [markdown]
# ### Functions

# %%
import requests
import jsonlines
from smart_open import open
import os
import json
import boto3
from impresso_commons.path.path_s3 import IMPRESSO_STORAGEOPT
from tqdm import tqdm

# %%
IML_baseuri = "https://impresso-project.ch/api/"
IML_articles_endpoint = os.path.join(IML_baseuri, "articles/")
IML_pages_endpoint = os.path.join(IML_baseuri, "pages/")

# %%
def get_total_contentitems(token):
    """Get total number of content items from IML."""
    response = requests.get(
        IML_articles_endpoint,
        headers={'Authorization': f'Bearer {jwt}'}
    )
    try:
        assert response.status_code == 200
    except Exception as e:
        raise e
        
    data = response.json()
    return data['total']

# %%
def get_contentitem_ids(skip, limit, token):
    """Get a bunch of content item IDs from IML."""
    payload = {
        "skip": skip,
        "limit": limit
    }
    response = requests.get(
        IML_articles_endpoint,
        headers={'Authorization': f'Bearer {jwt}'},
        params=payload
    )
    try:
        assert response.status_code == 200
    except Exception as e:
        print(response.status_code)
        raise e
        
    data = response.json()['data']
    return [
        {         
            "id": ci["uid"],
            "np": ci['newspaper']["uid"],
            "tp": ci["type"],
            "t": ci["title"]
        }
        for ci in data
    ]

# %%
def get_total_pages(token):
    """Get total number of pages from IML."""
    response = requests.get(
        IML_pages_endpoint,
        headers={'Authorization': f'Bearer {jwt}'}
    )
    print(f'Querying {IML_pages_endpoint}')
    try:
        assert response.status_code == 200
    except Exception as e:
        print(f'Got {response.status_code}')
        raise e
        
    data = response.json()
    return data

# %%
def get_page_ids(skip, limit, token):
    """Get a bunch of pages from IML."""
    payload = {
        "skip": skip,
        "limit": limit
    }
    response = requests.get(
        IML_pages_endpoint,
        headers={'Authorization': f'Bearer {jwt}'},
        params=payload
    )
    try:
        assert response.status_code == 200
    except Exception as e:
        print(IML_pages_endpoint)
        print(response.status_code)
        raise e
        
    data = response.json()['data']
    return [
        page
        for page in data
    ]

# %%
def write_snapshot_to_s3(data, path):
    
    session = boto3.Session(
        aws_access_key_id=IMPRESSO_STORAGEOPT['key'],
        aws_secret_access_key=IMPRESSO_STORAGEOPT['secret'],
    )
    
    transport_params = {
        'session': session,
        'resource_kwargs': {
            'endpoint_url': IMPRESSO_STORAGEOPT['client_kwargs']['endpoint_url'],
        }
    }
    
    with open(path, 'w', transport_params=transport_params) as outfile:
        
        with jsonlines.Writer(outfile) as writer:
            writer.write_all(data)
    
    return

# %% [markdown]
# ### Snapshot of Content Item IDs

# %%
# once logged in the impresso interface, the token can be found
# in the browser localstorage. For Chrome/Chromium go to: developer tools > application > localstorage
# and copy the value of variable `feathers_jwt`

jwt = "eyJhbGciOiJIUzI1NiIsInR5cCI6ImFjY2VzcyJ9..7VSuaJ8IpGDp3YWjFNMcQK1j0feK5Q2kWU76nNMA3pg"

# %%
req_limit = 100

# %%
total = get_total_contentitems(token=jwt)

# %%
offsets = list(range(0, total, req_limit))

# %%
len(offsets)
# Out:
# 273086

# %%
offsets[:1000]
# Out:
# [0,
#  100,
#  200,
#  300,
#  400,
#  500,
#  600,
#  700,
#  800,
#  900,
#  1000,
#  1100,
#  1200,
#  1300,
#  1400,
#  1500,
#  1600,
#  1700,
#  1800,
#  1900,
#  2000,
#  2100,
#  2200,
#  2300,
#  2400,
#  2500,
#  2600,
#  2700,
#  2800,
#  2900,
#  3000,
#  3100,
#  3200,
#  3300,
#  3400,
#  3500,
#  3600,
#  3700,
#  3800,
#  3900,
#  4000,
#  4100,
#  4200,
#  4300,
#  4400,
#  4500,
#  4600,
#  4700,
#  4800,
#  4900,
#  5000,
#  5100,
#  5200,
#  5300,
#  5400,
#  5500,
#  5600,
#  5700,
#  5800,
#  5900,
#  6000,
#  6100,
#  6200,
#  6300,
#  6400,
#  6500,
#  6600,
#  6700,
#  6800,
#  6900,
#  7000,
#  7100,
#  7200,
#  7300,
#  7400,
#  7500,
#  7600,
#  7700,
#  7800,
#  7900,
#  8000,
#  8100,
#  8200,
#  8300,
#  8400,
#  8500,
#  8600,
#  8700,
#  8800,
#  8900,
#  9000,
#  9100,
#  9200,
#  9300,
#  9400,
#  9500,
#  9600,
#  9700,
#  9800,
#  9900,
#  10000,
#  10100,
#  10200,
#  10300,
#  10400,
#  10500,
#  10600,
#  10700,
#  10800,
#  10900,
#  11000,
#  11100,
#  11200,
#  11300,
#  11400,
#  11500,
#  11600,
#  11700,
#  11800,
#  11900,
#  12000,
#  12100,
#  12200,
#  12300,
#  12400,
#  12500,
#  12600,
#  12700,
#  12800,
#  12900,
#  13000,
#  13100,
#  13200,
#  13300,
#  13400,
#  13500,
#  13600,
#  13700,
#  13800,
#  13900,
#  14000,
#  14100,
#  14200,
#  14300,
#  14400,
#  14500,
#  14600,
#  14700,
#  14800,
#  14900,
#  15000,
#  15100,
#  15200,
#  15300,
#  15400,
#  15500,
#  15600,
#  15700,
#  15800,
#  15900,
#  16000,
#  16100,
#  16200,
#  16300,
#  16400,
#  16500,
#  16600,
#  16700,
#  16800,
#  16900,
#  17000,
#  17100,
#  17200,
#  17300,
#  17400,
#  17500,
#  17600,
#  17700,
#  17800,
#  17900,
#  18000,
#  18100,
#  18200,
#  18300,
#  18400,
#  18500,
#  18600,
#  18700,
#  18800,
#  18900,
#  19000,
#  19100,
#  19200,
#  19300,
#  19400,
#  19500,
#  19600,
#  19700,
#  19800,
#  19900,
#  20000,
#  20100,
#  20200,
#  20300,
#  20400,
#  20500,
#  20600,
#  20700,
#  20800,
#  20900,
#  21000,
#  21100,
#  21200,
#  21300,
#  21400,
#  21500,
#  21600,
#  21700,
#  21800,
#  21900,
#  22000,
#  22100,
#  22200,
#  22300,
#  22400,
#  22500,
#  22600,
#  22700,
#  22800,
#  22900,
#  23000,
#  23100,
#  23200,
#  23300,
#  23400,
#  23500,
#  23600,
#  23700,
#  23800,
#  23900,
#  24000,
#  24100,
#  24200,
#  24300,
#  24400,
#  24500,
#  24600,
#  24700,
#  24800,
#  24900,
#  25000,
#  25100,
#  25200,
#  25300,
#  25400,
#  25500,
#  25600,
#  25700,
#  25800,
#  25900,
#  26000,
#  26100,
#  26200,
#  26300,
#  26400,
#  26500,
#  26600,
#  26700,
#  26800,
#  26900,
#  27000,
#  27100,
#  27200,
#  27300,
#  27400,
#  27500,
#  27600,
#  27700,
#  27800,
#  27900,
#  28000,
#  28100,
#  28200,
#  28300,
#  28400,
#  28500,
#  28600,
#  28700,
#  28800,
#  28900,
#  29000,
#  29100,
#  29200,
#  29300,
#  29400,
#  29500,
#  29600,
#  29700,
#  29800,
#  29900,
#  30000,
#  30100,
#  30200,
#  30300,
#  30400,
#  30500,
#  30600,
#  30700,
#  30800,
#  30900,
#  31000,
#  31100,
#  31200,
#  31300,
#  31400,
#  31500,
#  31600,
#  31700,
#  31800,
#  31900,
#  32000,
#  32100,
#  32200,
#  32300,
#  32400,
#  32500,
#  32600,
#  32700,
#  32800,
#  32900,
#  33000,
#  33100,
#  33200,
#  33300,
#  33400,
#  33500,
#  33600,
#  33700,
#  33800,
#  33900,
#  34000,
#  34100,
#  34200,
#  34300,
#  34400,
#  34500,
#  34600,
#  34700,
#  34800,
#  34900,
#  35000,
#  35100,
#  35200,
#  35300,
#  35400,
#  35500,
#  35600,
#  35700,
#  35800,
#  35900,
#  36000,
#  36100,
#  36200,
#  36300,
#  36400,
#  36500,
#  36600,
#  36700,
#  36800,
#  36900,
#  37000,
#  37100,
#  37200,
#  37300,
#  37400,
#  37500,
#  37600,
#  37700,
#  37800,
#  37900,
#  38000,
#  38100,
#  38200,
#  38300,
#  38400,
#  38500,
#  38600,
#  38700,
#  38800,
#  38900,
#  39000,
#  39100,
#  39200,
#  39300,
#  39400,
#  39500,
#  39600,
#  39700,
#  39800,
#  39900,
#  40000,
#  40100,
#  40200,
#  40300,
#  40400,
#  40500,
#  40600,
#  40700,
#  40800,
#  40900,
#  41000,
#  41100,
#  41200,
#  41300,
#  41400,
#  41500,
#  41600,
#  41700,
#  41800,
#  41900,
#  42000,
#  42100,
#  42200,
#  42300,
#  42400,
#  42500,
#  42600,
#  42700,
#  42800,
#  42900,
#  43000,
#  43100,
#  43200,
#  43300,
#  43400,
#  43500,
#  43600,
#  43700,
#  43800,
#  43900,
#  44000,
#  44100,
#  44200,
#  44300,
#  44400,
#  44500,
#  44600,
#  44700,
#  44800,
#  44900,
#  45000,
#  45100,
#  45200,
#  45300,
#  45400,
#  45500,
#  45600,
#  45700,
#  45800,
#  45900,
#  46000,
#  46100,
#  46200,
#  46300,
#  46400,
#  46500,
#  46600,
#  46700,
#  46800,
#  46900,
#  47000,
#  47100,
#  47200,
#  47300,
#  47400,
#  47500,
#  47600,
#  47700,
#  47800,
#  47900,
#  48000,
#  48100,
#  48200,
#  48300,
#  48400,
#  48500,
#  48600,
#  48700,
#  48800,
#  48900,
#  49000,
#  49100,
#  49200,
#  49300,
#  49400,
#  49500,
#  49600,
#  49700,
#  49800,
#  49900,
#  50000,
#  50100,
#  50200,
#  50300,
#  50400,
#  50500,
#  50600,
#  50700,
#  50800,
#  50900,
#  51000,
#  51100,
#  51200,
#  51300,
#  51400,
#  51500,
#  51600,
#  51700,
#  51800,
#  51900,
#  52000,
#  52100,
#  52200,
#  52300,
#  52400,
#  52500,
#  52600,
#  52700,
#  52800,
#  52900,
#  53000,
#  53100,
#  53200,
#  53300,
#  53400,
#  53500,
#  53600,
#  53700,
#  53800,
#  53900,
#  54000,
#  54100,
#  54200,
#  54300,
#  54400,
#  54500,
#  54600,
#  54700,
#  54800,
#  54900,
#  55000,
#  55100,
#  55200,
#  55300,
#  55400,
#  55500,
#  55600,
#  55700,
#  55800,
#  55900,
#  56000,
#  56100,
#  56200,
#  56300,
#  56400,
#  56500,
#  56600,
#  56700,
#  56800,
#  56900,
#  57000,
#  57100,
#  57200,
#  57300,
#  57400,
#  57500,
#  57600,
#  57700,
#  57800,
#  57900,
#  58000,
#  58100,
#  58200,
#  58300,
#  58400,
#  58500,
#  58600,
#  58700,
#  58800,
#  58900,
#  59000,
#  59100,
#  59200,
#  59300,
#  59400,
#  59500,
#  59600,
#  59700,
#  59800,
#  59900,
#  60000,
#  60100,
#  60200,
#  60300,
#  60400,
#  60500,
#  60600,
#  60700,
#  60800,
#  60900,
#  61000,
#  61100,
#  61200,
#  61300,
#  61400,
#  61500,
#  61600,
#  61700,
#  61800,
#  61900,
#  62000,
#  62100,
#  62200,
#  62300,
#  62400,
#  62500,
#  62600,
#  62700,
#  62800,
#  62900,
#  63000,
#  63100,
#  63200,
#  63300,
#  63400,
#  63500,
#  63600,
#  63700,
#  63800,
#  63900,
#  64000,
#  64100,
#  64200,
#  64300,
#  64400,
#  64500,
#  64600,
#  64700,
#  64800,
#  64900,
#  65000,
#  65100,
#  65200,
#  65300,
#  65400,
#  65500,
#  65600,
#  65700,
#  65800,
#  65900,
#  66000,
#  66100,
#  66200,
#  66300,
#  66400,
#  66500,
#  66600,
#  66700,
#  66800,
#  66900,
#  67000,
#  67100,
#  67200,
#  67300,
#  67400,
#  67500,
#  67600,
#  67700,
#  67800,
#  67900,
#  68000,
#  68100,
#  68200,
#  68300,
#  68400,
#  68500,
#  68600,
#  68700,
#  68800,
#  68900,
#  69000,
#  69100,
#  69200,
#  69300,
#  69400,
#  69500,
#  69600,
#  69700,
#  69800,
#  69900,
#  70000,
#  70100,
#  70200,
#  70300,
#  70400,
#  70500,
#  70600,
#  70700,
#  70800,
#  70900,
#  71000,
#  71100,
#  71200,
#  71300,
#  71400,
#  71500,
#  71600,
#  71700,
#  71800,
#  71900,
#  72000,
#  72100,
#  72200,
#  72300,
#  72400,
#  72500,
#  72600,
#  72700,
#  72800,
#  72900,
#  73000,
#  73100,
#  73200,
#  73300,
#  73400,
#  73500,
#  73600,
#  73700,
#  73800,
#  73900,
#  74000,
#  74100,
#  74200,
#  74300,
#  74400,
#  74500,
#  74600,
#  74700,
#  74800,
#  74900,
#  75000,
#  75100,
#  75200,
#  75300,
#  75400,
#  75500,
#  75600,
#  75700,
#  75800,
#  75900,
#  76000,
#  76100,
#  76200,
#  76300,
#  76400,
#  76500,
#  76600,
#  76700,
#  76800,
#  76900,
#  77000,
#  77100,
#  77200,
#  77300,
#  77400,
#  77500,
#  77600,
#  77700,
#  77800,
#  77900,
#  78000,
#  78100,
#  78200,
#  78300,
#  78400,
#  78500,
#  78600,
#  78700,
#  78800,
#  78900,
#  79000,
#  79100,
#  79200,
#  79300,
#  79400,
#  79500,
#  79600,
#  79700,
#  79800,
#  79900,
#  80000,
#  80100,
#  80200,
#  80300,
#  80400,
#  80500,
#  80600,
#  80700,
#  80800,
#  80900,
#  81000,
#  81100,
#  81200,
#  81300,
#  81400,
#  81500,
#  81600,
#  81700,
#  81800,
#  81900,
#  82000,
#  82100,
#  82200,
#  82300,
#  82400,
#  82500,
#  82600,
#  82700,
#  82800,
#  82900,
#  83000,
#  83100,
#  83200,
#  83300,
#  83400,
#  83500,
#  83600,
#  83700,
#  83800,
#  83900,
#  84000,
#  84100,
#  84200,
#  84300,
#  84400,
#  84500,
#  84600,
#  84700,
#  84800,
#  84900,
#  85000,
#  85100,
#  85200,
#  85300,
#  85400,
#  85500,
#  85600,
#  85700,
#  85800,
#  85900,
#  86000,
#  86100,
#  86200,
#  86300,
#  86400,
#  86500,
#  86600,
#  86700,
#  86800,
#  86900,
#  87000,
#  87100,
#  87200,
#  87300,
#  87400,
#  87500,
#  87600,
#  87700,
#  87800,
#  87900,
#  88000,
#  88100,
#  88200,
#  88300,
#  88400,
#  88500,
#  88600,
#  88700,
#  88800,
#  88900,
#  89000,
#  89100,
#  89200,
#  89300,
#  89400,
#  89500,
#  89600,
#  89700,
#  89800,
#  89900,
#  90000,
#  90100,
#  90200,
#  90300,
#  90400,
#  90500,
#  90600,
#  90700,
#  90800,
#  90900,
#  91000,
#  91100,
#  91200,
#  91300,
#  91400,
#  91500,
#  91600,
#  91700,
#  91800,
#  91900,
#  92000,
#  92100,
#  92200,
#  92300,
#  92400,
#  92500,
#  92600,
#  92700,
#  92800,
#  92900,
#  93000,
#  93100,
#  93200,
#  93300,
#  93400,
#  93500,
#  93600,
#  93700,
#  93800,
#  93900,
#  94000,
#  94100,
#  94200,
#  94300,
#  94400,
#  94500,
#  94600,
#  94700,
#  94800,
#  94900,
#  95000,
#  95100,
#  95200,
#  95300,
#  95400,
#  95500,
#  95600,
#  95700,
#  95800,
#  95900,
#  96000,
#  96100,
#  96200,
#  96300,
#  96400,
#  96500,
#  96600,
#  96700,
#  96800,
#  96900,
#  97000,
#  97100,
#  97200,
#  97300,
#  97400,
#  97500,
#  97600,
#  97700,
#  97800,
#  97900,
#  98000,
#  98100,
#  98200,
#  98300,
#  98400,
#  98500,
#  98600,
#  98700,
#  98800,
#  98900,
#  99000,
#  99100,
#  99200,
#  99300,
#  99400,
#  99500,
#  99600,
#  99700,
#  99800,
#  99900]

# %%
ci_ids = []

for offset in tqdm(offsets):
     ci_ids += get_contentitem_ids(offset, limit=req_limit, token=jwt)
# Out:
#   4%|▎         | 9749/273086 [2:54:15<107:51:04,  1.47s/it]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/share/virtualenvs/impresso-data-sanitycheck-GtjVwJM6/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-720ff6b8ed24> in <module>
#       2
#       3 for offset in tqdm(offsets):
# ----> 4      ci_ids += get_contentitem_ids(offset, limit=req_limit, token=jwt)
#
# <ipython-input-4-4e8a02ebbab9> in get_contentitem_ids(skip, limit, token)
#       8         IML_articles_endpoint,
#       9         headers={'Authorization': f'Bearer {jwt}'},
# ---> 10         params=payload
#      11     )
#      12     try:
#
# ~/.local/share/virtualenvs/impresso-data-sanitycheck-GtjVwJM6/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/.local/share/virtualenvs/impresso-data-sanitycheck-GtjVwJM6/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/.local/share/virtualenvs/impresso-data-sanitycheck-GtjVwJM6/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/.local/share/virtualenvs/impresso-data-sanitycheck-GtjVwJM6/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/.local/share/virtualenvs/impresso-data-sanitycheck-GtjVwJM6/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/.local/share/virtualenvs/impresso-data-sanitycheck-GtjVwJM6/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/.local/share/virtualenvs/impresso-data-sanitycheck-GtjVwJM6/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/.pyenv/versions/3.6.7/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~/.pyenv/versions/3.6.7/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~/.pyenv/versions/3.6.7/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~/.pyenv/versions/3.6.7/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/.pyenv/versions/3.6.7/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# ~/.pyenv/versions/3.6.7/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# ~/.pyenv/versions/3.6.7/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
ci_ids
# Out:
# [{'id': 'IMP-2002-04-23-a-i0172', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0198', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0255', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0298', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0037', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0084', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0105', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0123', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0173', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0199', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0217', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0256', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0299', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0020', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0038', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0085', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0106', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0124', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0174', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0200', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0218', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0257', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0086', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0107', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0125', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0175', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0201', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0219', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0258', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0313', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0126', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0202', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0220', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0259', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0302', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0127', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0168', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0177', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0203', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0221', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0260', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0303', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0031', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0128', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0178', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0204', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0222', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0129', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0205', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0091', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0130', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0206', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0092', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0208', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-23-a-i0209', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0023', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0032', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0063', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0071', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0085', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0086', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0087', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0127', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0147', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0229', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0238', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0284', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0033', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0072', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0088', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0128', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0148', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0192', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0230', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0239', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0278', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0034', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0073', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0089', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0129', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0149', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0193', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0231', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0240', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0258', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0317', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0035', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0074', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0090', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0130', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0150', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0194', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0232', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0241', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0259', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0282', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0318', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0036', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0075', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0091', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0120', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0131', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0151', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0195', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0233', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0242', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0260', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0319', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0037', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0092', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0121', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0132', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0152', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0196', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0205', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0234', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0243', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0261', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0320', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0038', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0093', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0133', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0159', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0197', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0206', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0244', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0262', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0321', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0039', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0094', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0134', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0160', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0198', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0245', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0263', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0040', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0059', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0095', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0135', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0264', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0333', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0041', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0096', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0146', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0265', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0042', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0061', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0043', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0062', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0098', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0044', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0045', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0046', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-04-24-a-i0050', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0034', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0062', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0075', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0076', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0094', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0136', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0174', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0192', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0210', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0218', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0249', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0265', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0311', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0219', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0250', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0266', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0312', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0176', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0194', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0220', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0251', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0267', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0276', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0313', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0195', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0221', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0252', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0277', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0314', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0178', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0196', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0222', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0315', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0179', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0197', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0223', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0254', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0316', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0180', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0198', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0224', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0255', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0317', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0041', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0181', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0199', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0225', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0182', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0200', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0226', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0128', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0161', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0183', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0201', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0162', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0184', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0202', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0228', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0033', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0185', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0203', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0229', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0186', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0230', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0205', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0231', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0206', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0232', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0207', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0233', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0208', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0234', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0209', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0235', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0236', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0237', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-03-a-i0238', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0031', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0065', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0078', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0086', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0114', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0126', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0138', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0229', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0240', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0251', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0290', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0324', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0231', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0141', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0230', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0241', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0232', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0243', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0255', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0082', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0067', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0080', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0142', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0193', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0244', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0256', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0083', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0194', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0234', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0245', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0295', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0084', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0195', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0235', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0289', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0296', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0085', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0196', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0218', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0236', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0247', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0297', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0030', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0197', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0237', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0248', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0298', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0040', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0198', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0238', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0249', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0299', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0096', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0199', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0239', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0250', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0042', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0200', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0043', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0201', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0044', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0202', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0045', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0203', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0204', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0205', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0206', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0207', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0208', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0209', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-04-a-i0210', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0062', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0077', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0139', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0170', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0234', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0281', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0321', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0063', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0140', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0171', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0282', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0322', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0064', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0141', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0172', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0236', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0283', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0323', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0004', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0065', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0142', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0173', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0223', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0237', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0284', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0324', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0060', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0143', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0174', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0210', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0224', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0238', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0285', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0325', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0067', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0144', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0175', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0211', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0239', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0326', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0068', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0145', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0176', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0240', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0287', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0327', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0069', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0177', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0213', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0241', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0328', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0178', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0214', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0071', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0179', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0072', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0180', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0216', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0073', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0181', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0217', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0332', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0013', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0074', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0218', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0333', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0075', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0334', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-07-05-a-i0076', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0033', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0068', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0069', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0070', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0099', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0137', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0181', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0219', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0247', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0279', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0286', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0306', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0307', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0314', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0323', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0332', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0338', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0346', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0350', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0356', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0375', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0376', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0383', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0034', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0071', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0100', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0138', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0182', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0220', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0248', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0287', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0308', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0315', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0324', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0333', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0339', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0351', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0357', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0003',
#   'np': 'IMP',
#   'tp': 'ar',
#   't': 'Restaurateurs insatisfaits'},
#  {'id': 'IMP-2002-03-26-a-i0035', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0072', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0101', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0139', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0183', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0221', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0249', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0288', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0309', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0316', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0325', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0334', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0340', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0358', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0036', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0073', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0097', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0102', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0140', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0184', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0222', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0250', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0289', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0326', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0341', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0005',
#   'np': 'IMP',
#   'tp': 'ar',
#   't': 'Décision imminente'},
#  {'id': 'IMP-2002-03-26-a-i0037', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0074', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0098', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0103', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0122',
#   'np': 'IMP',
#   'tp': 'ar',
#   't': 'Le tireur en détention provisoire'},
#  {'id': 'IMP-2002-03-26-a-i0141', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0166',
#   'np': 'IMP',
#   'tp': 'ar',
#   't': 'La mémoire menacée'},
#  {'id': 'IMP-2002-03-26-a-i0179', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0185', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0223', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0251', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0290', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0006',
#   'np': 'IMP',
#   'tp': 'ar',
#   't': 'Métiers sous la loupe'},
#  {'id': 'IMP-2002-03-26-a-i0038', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0075', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0104', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0142', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0148', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0186', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0224', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0252', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0291', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0303', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0022', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0039', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0076', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0105', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0149', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0187', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0225', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0253', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0292', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0040', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0077', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0106', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0125', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0134',
#   'np': 'IMP',
#   'tp': 'ar',
#   't': 'IARÉGIQNPRATI0IIF'},
#  {'id': 'IMP-2002-03-26-a-i0226', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0254', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0293', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0305', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0032', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0078', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0107', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0227', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0255', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0294', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0079', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0108', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0228', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0080', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0081', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0082', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0083', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0084', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0085', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0086', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0087', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0088', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0089', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0090', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0091', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0092', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-26-a-i0093', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0036', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0044', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0053', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0064', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0065', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0066', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0112', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0155', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0185', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0202', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0240', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0255', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0264', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0037', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0067', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0094',
#   'np': 'IMP',
#   'tp': 'ar',
#   't': 'Handicapés enfin libérés'},
#  {'id': 'IMP-2002-03-27-a-i0113', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0156', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0186', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0203', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0241', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0256', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0265', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0018', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0038', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0068', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0114', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0157', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0187', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0204', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0242', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0257', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0266', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0019', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0039', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0069', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0084', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0115', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0158', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0188', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0205', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0228', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0232', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0243', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0258',
#   'np': 'IMP',
#   'tp': 'ar',
#   't': 'VAL-DE-TRAVERS'},
#  {'id': 'IMP-2002-03-27-a-i0267', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0020', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0040', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0070', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0107',
#   'np': 'IMP',
#   'tp': 'ar',
#   't': 'IARÉGIQNPRATIOIIF'},
#  {'id': 'IMP-2002-03-27-a-i0116', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0159', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0189', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0206', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0244', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0268', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0021', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0041', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0071', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0117', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0160', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0190', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0207', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0245', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0279', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0022', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0042', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0118', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0175', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0191', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0023', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0043', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0119', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0192', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0024', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0111', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0120', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0263', 'np': 'IMP', 'tp': 'ar', 't': 'VAL-DE-RUZ'},
#  {'id': 'IMP-2002-03-27-a-i0035', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0121', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0122', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0123', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0124', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0125', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0126', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0127', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-27-a-i0128', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0031', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0047', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0078', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0079', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0088', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0105', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0119', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0144', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0160', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0186',
#   'np': 'IMP',
#   'tp': 'ar',
#   't': 'Les femmes arrivent'},
#  {'id': 'IMP-2002-03-28-a-i0257', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0304', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0338', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0032', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0048', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0089', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0106', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0120', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0145', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0161', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0249', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0339', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0033', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0049', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0090', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0107', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0121', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0146', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0162', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0201', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0332',
#   'np': 'IMP',
#   'tp': 'ar',
#   't': 'VAL-DE-TRAVERS'},
#  {'id': 'IMP-2002-03-28-a-i0340', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0034', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0038',
#   'np': 'IMP',
#   'tp': 'ar',
#   't': 'Deux interpellations'},
#  {'id': 'IMP-2002-03-28-a-i0050', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0091', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0108', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0122', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0147', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0163', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0202', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0237', 'np': 'IMP', 'tp': 'ar', 't': 'FLÉCHETTES'},
#  {'id': 'IMP-2002-03-28-a-i0299', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0307', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0341', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0005',
#   'np': 'IMP',
#   'tp': 'ar',
#   't': 'Fermeture du zoo'},
#  {'id': 'IMP-2002-03-28-a-i0051', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0092', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0109', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0123', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0148', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0164', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0176', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0203', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0300',
#   'np': 'IMP',
#   'tp': 'ar',
#   't': 'Rallonge demandée'},
#  {'id': 'IMP-2002-03-28-a-i0021', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0052', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0093', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0110', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0124', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0149', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0165', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0204', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0053', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0094', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0111', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0125', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0150', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0157',
#   'np': 'IMP',
#   'tp': 'ar',
#   't': 'IAREGIQNPRATIQIIF'},
#  {'id': 'IMP-2002-03-28-a-i0166', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0205', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0230', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0302', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0336', 'np': 'IMP', 'tp': 'ar', 't': 'VAL-DE-RUZ'},
#  {'id': 'IMP-2002-03-28-a-i0355', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0054', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0095', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0112', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0126', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0167', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0206', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0291', 'np': 'IMP', 'tp': 'ar', 't': 'Glock'},
#  {'id': 'IMP-2002-03-28-a-i0303', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0030', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0055', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0113', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0127', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0159', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0168', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0207', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0044', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0056', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0114', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0128', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0169', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0208', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0266', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0045', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0057', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0115', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0129', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-03-28-a-i0170', 'np': 'IMP', 'tp': 'ad', 't': ''},
# ...
#  {'id': 'IMP-2002-01-08-a-i0154', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0174', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0225', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0018', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0039', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0072', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0155', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0175', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0226', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0019', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0040', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0073', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0156', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0176', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0193', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0219',
#   'np': 'IMP',
#   'tp': 'ar',
#   't': 'VAL-DE-TRAVERS .'},
#  {'id': 'IMP-2002-01-08-a-i0227', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0020', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0041', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0074', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0157', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0177', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0194', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0228', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0021', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0042', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0075', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0158', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0178', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0229', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0240',
#   'np': 'IMP',
#   'tp': 'ar',
#   't': 'IFDESSINniimilR'},
#  {'id': 'IMP-2002-01-08-a-i0022', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0043', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0067', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0076', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0159', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0023', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0036', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0044', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0077', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0118',
#   'np': 'IMP',
#   'tp': 'ar',
#   't': 'Contrat pro pour Sigrist'},
#  {'id': 'IMP-2002-01-08-a-i0151',
#   'np': 'IMP',
#   'tp': 'ar',
#   't': '& mm om tmv &lt;A MIZ ~ ^ \\'},
#  {'id': 'IMP-2002-01-08-a-i0160', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0223', 'np': 'IMP', 'tp': 'ar', 't': 'VAL-DE-RUZ'},
#  {'id': 'IMP-2002-01-08-a-i0024', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0045', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0078', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0161', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0025', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0046', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0162', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0026', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0047', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0027', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0048', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0028', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-01-08-a-i0049', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0016', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0028', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0038', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0039', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0054', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0073', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0152', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0164', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0192', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0198', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0017', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0055', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0074', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0153', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0199', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0018', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0056', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0075', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0139', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0154', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0200', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0212',
#   'np': 'IMP',
#   'tp': 'ar',
#   't': 'IFDESSI INDU 101IR ,'},
#  {'id': 'IMP-2002-01-09-a-i0019', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0057', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0076', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0155', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0201', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0058', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0077', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0156', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0202', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0059', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0157', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0203', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0046', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0060', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0102',
#   'np': 'IMP',
#   'tp': 'ar',
#   't': 'Un pas vers la victoire'},
#  {'id': 'IMP-2002-01-09-a-i0158', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0204', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0061', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0159', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0205', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0009',
#   'np': 'IMP',
#   'tp': 'ar',
#   't': 'Une élection indécise'},
#  {'id': 'IMP-2002-01-09-a-i0062', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0160', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0182',
#   'np': 'IMP',
#   'tp': 'ar',
#   't': "Ordre d'expulsion"},
#  {'id': 'IMP-2002-01-09-a-i0206', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0063', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0161', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0064', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0106',
#   'np': 'IMP',
#   'tp': 'ar',
#   't': 'Naissance de deux sociétés'},
#  {'id': 'IMP-2002-01-09-a-i0162', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0065', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-01-09-a-i0163', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0001', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0049', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0050', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0060', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0065', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0072', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0087', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0125', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0149', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0156', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0188', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0250', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0291', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0330', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0061', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0073', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0088', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0126', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0150', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0157', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0189', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0224', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0239', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0243', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0247', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0251', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0292', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0331', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0003',
#   'np': 'IMP',
#   'tp': 'ar',
#   't': 'Deux jours de «Cup»'},
#  {'id': 'IMP-2002-05-17-a-i0062', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0074', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0089', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0127', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0151', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0158', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0167',
#   'np': 'IMP',
#   'tp': 'ar',
#   't': 'LES MOTS CROISÉS DU JOUR NoiSQ'},
#  {'id': 'IMP-2002-05-17-a-i0190', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0225', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0252', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0293', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0332', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0063', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0075', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0090', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0128', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0152', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0159', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0191', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0226', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0253', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0294', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0333', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0064', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0070', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0076', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0091', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0111', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0129', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0153', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0160', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0192', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0227', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0295', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0334', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0071', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0077', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0092', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0130', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0161', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0186', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0193', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0221', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0289',
#   'np': 'IMP',
#   'tp': 'ar',
#   't': 'Coûts en hausse'},
#  {'id': 'IMP-2002-05-17-a-i0296', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0335', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0021', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0047', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0078', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0093', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0131', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0162', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0171', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0194', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0222', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0270',
#   'np': 'IMP',
#   'tp': 'ar',
#   't': "i LES JEUX DU VENDREDI'"},
#  {'id': 'IMP-2002-05-17-a-i0297', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0336', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0048', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0079', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0094', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0123', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0163', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0172', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0195', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0236', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0298', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0329', 'np': 'IMP', 'tp': 'ar', 't': 'VAL-DE-RUZ'},
#  {'id': 'IMP-2002-05-17-a-i0350', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0080', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0095', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0106',
#   'np': 'IMP',
#   'tp': 'ar',
#   't': "D Service d'Incendie et de Secours des Montagnes neuchâteloises"},
#  {'id': 'IMP-2002-05-17-a-i0115', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0124', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0164', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0196', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0272',
#   'np': 'IMP',
#   'tp': 'ar',
#   't': 'SCRABBLE Le top en 3 minutes'},
#  {'id': 'IMP-2002-05-17-a-i0299', 'np': 'IMP', 'tp': 'ar', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0081', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0096', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0197', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0300', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0032', 'np': 'IMP', 'tp': 'ad', 't': ''},
#  {'id': 'IMP-2002-05-17-a-i0082', 'np': 'IMP', 'tp': 'ar', 't': ''}]

# %%
write_snapshot_to_s3(
    ci_ids,
    "s3://snapshots/alpha/iml.jsonl.bz2"
)

# %% [markdown]
# ### Snapshot of pages

# %%
total_pages = get_total_pages(token=jwt)

# %%
total_pages
# Out:
# 27308519

# %%
pages_offsets = list(range(0, total, req_limit))

# %%
page_ids = []

for offset in tqdm(pages_offsets[:1]):
    page_ids += get_page_ids(offset, limit=req_limit, token=jwt)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 405
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-37-345323f341b0> in <module>
#       2
#       3 for offset in tqdm(pages_offsets[:1]):
# ----> 4     page_ids += get_page_ids(offset, limit=req_limit, token=jwt)
#
# <ipython-input-36-3cdda766619f> in get_page_ids(skip, limit, token)
#      14     except Exception as e:
#      15         print(response.status_code)
# ---> 16         raise e
#      17
#      18     data = response.json()['data']
#
# <ipython-input-36-3cdda766619f> in get_page_ids(skip, limit, token)
#      11     )
#      12     try:
# ---> 13         assert response.status_code == 200
#      14     except Exception as e:
#      15         print(response.status_code)
#
# AssertionError:

# %% [markdown]
# #### Snapshot of Page IDs

# %% [markdown]
# ## MySQL snapshots

# %%
import impresso_db
from impresso_db.base import Session, engine

# %%
os.environ["IMPRESSO_DB_CONFIG"] = "prod"

# %%
# %%time
with engine.connect() as db_conn:
    q = "SELECT id, newspaper_id, title, type FROM impresso.content_items;"
    ids = db_conn.execute(q)
# Out:
# CPU times: user 4min 14s, sys: 12.9 s, total: 4min 27s
# Wall time: 4min 27s

# %%
mysql_ci_ids = [
    {
        "id": ci_id,
        "np": np_id,
        "tp": ci_type,
        "t": ci_title
    }
    for ci_id, np_id, ci_title, ci_type in ids
]

# %%
len(mysql_ci_ids)
# Out:
# 26521317

# %%
write_snapshot_to_s3(
    mysql_ci_ids,
    "s3://snapshots/alpha/mysql.jsonl.bz2"
)

# %%
# !s3cmd ls s3://snapshots/alpha/
# Out:
# 2019-05-10 10:43      2828   s3://snapshots/alpha/iml.jsonl.bz2
# 2019-05-10 07:49      2803   s3://snapshots/alpha/iml.txt.bz2
# 2019-05-13 10:22 190696389   s3://snapshots/alpha/mysql.jsonl.bz2
